# %%
# !pip install pandas

# %%
# !pip install matplotlib

# %%
# !pip install numpy

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
price_data = pd.read_csv(f'https://raw.githubusercontent.com/JinyuLiu0116/Stock_Price_Data_Pipeline_and_Analysis/main/daily_IBM.csv')
print(price_data)
# Out:
#      timestamp    open     high       low   close   volume
# 0   2024-07-05  175.74  176.090  173.9500  176.02  2085970
# 1   2024-07-03  177.88  177.980  175.1700  175.73  1649049
# 2   2024-07-02  174.84  177.485  174.3200  177.30  2883275
# 3   2024-07-01  173.45  176.460  173.3800  175.10  3320961
# 4   2024-06-28  170.85  173.460  170.5300  172.95  4193459
# ..         ...     ...      ...       ...     ...      ...
# 95  2024-02-16  186.63  188.950  185.9452  187.64  4842840
# 96  2024-02-15  183.62  186.980  183.6200  186.87  4714301
# 97  2024-02-14  185.00  185.000  182.2600  183.57  3173391
# 98  2024-02-13  184.28  184.770  182.3600  183.70  4290453
# 99  2024-02-12  185.90  186.480  184.0300  186.16  4724021
#
# [100 rows x 6 columns]

# %%
price_data.head(10)
# Out:
#     timestamp    open      high     low   close    volume
# 0  2024-07-05  175.74  176.0900  173.95  176.02   2085970
# 1  2024-07-03  177.88  177.9800  175.17  175.73   1649049
# 2  2024-07-02  174.84  177.4850  174.32  177.30   2883275
# 3  2024-07-01  173.45  176.4600  173.38  175.10   3320961
# 4  2024-06-28  170.85  173.4600  170.53  172.95   4193459
# 5  2024-06-27  171.12  172.5000  170.48  170.85   2894001
# 6  2024-06-26  171.28  172.6800  170.41  171.87   2779016
# 7  2024-06-25  175.14  175.7526  171.42  172.60   4119267
# 8  2024-06-24  175.00  178.4599  174.15  175.01   4864735
# 9  2024-06-21  173.97  174.9600  171.40  172.46  10182025

# %%
price_data.tail(10)
# Out:
#      timestamp    open     high       low   close   volume
# 90  2024-02-26  185.60  186.125  184.0600  184.13  4620815
# 91  2024-02-23  184.90  186.455  184.5700  185.72  3433800
# 92  2024-02-22  182.45  184.550  181.9300  184.21  5078398
# 93  2024-02-21  182.56  183.030  178.7500  179.70  4728473
# 94  2024-02-20  187.64  188.770  183.0600  183.44  4247181
# 95  2024-02-16  186.63  188.950  185.9452  187.64  4842840
# 96  2024-02-15  183.62  186.980  183.6200  186.87  4714301
# 97  2024-02-14  185.00  185.000  182.2600  183.57  3173391
# 98  2024-02-13  184.28  184.770  182.3600  183.70  4290453
# 99  2024-02-12  185.90  186.480  184.0300  186.16  4724021

# %%
price_data.count()
# Out:
# timestamp    100
# open         100
# high         100
# low          100
# close        100
# volume       100
# dtype: int64

# %%
ax = sns.lineplot(x='date', y='value', data=df)
ax.xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%m-%d'))

# %%
plt.figure(figsize=(11, 6))
y={'02-12','03-12','04-12','05-12','06-12','07-05'}
plt.title('IMB Stock Price Over Time (in USD)')
plt.plot(price_data.timestamp, price_data.high, label='highest price', color='green',marker='.')
plt.plot(price_data.timestamp, price_data.low,label='lowest price', color='red',marker='.')
plt.ylabel('Price In USD')

plt.legend()
plt.show()

# %%
plt.figure(figsize=(11, 6))
plt.title('IMB Stock Price Over Time (in USD)')
plt.plot(price_data.timestamp, price_data.open,label='open price', color='brown',marker='.', markersize=5)
plt.plot(price_data.timestamp, price_data.close, label='close price', color='blue',marker='.', markersize=5)
plt.ylabel('Price In USD')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(price_data.timestamp, price_data.volume, label ='volume')
plt.legend()
plt.show()
