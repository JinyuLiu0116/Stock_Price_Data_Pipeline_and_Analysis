# %%
# !pip install pandas
# !pip install matplotlib
# !pip install yfinance

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import numpy as np
import datetime as dt

# %%
data=pd.read_csv('https://raw.githubusercontent.com/JinyuLiu0116/Stock_Price_Data_Pipeline_and_Analysis/main/CRWD.csv?token=GHSAT0AAAAAACTVWJPIHA6TNFDUKEC5M4RUZU35JUQ')

# %%
data1=pd.read_csv('https://raw.githubusercontent.com/JinyuLiu0116/Stock_Price_Data_Pipeline_and_Analysis/main/trans_crdwstock_data%20(15m).csv?token=GHSAT0AAAAAACTVWJPI6ZSE22EJ56QK7LHOZU354LQ')

# %%
data.count()
# Out:
# Date         137
# Open         137
# High         137
# Low          137
# Close        137
# Adj Close    137
# Volume       137
# dtype: int64

# %%
data1.head(100)
# Out:
#           Date      Time     Open     High      Low    Close  Volume
# 0   2024-07-19  19:45:00  302.202  302.470  302.000  302.440   12452
# 1   2024-07-19  19:30:00  301.990  316.750  295.000  302.220   40467
# 2   2024-07-19  19:15:00  301.570  302.200  301.570  302.200    8713
# 3   2024-07-19  19:00:00  302.250  302.400  301.500  301.930   10239
# 4   2024-07-19  18:45:00  302.190  302.460  302.000  302.400    7688
# ..         ...       ...      ...      ...      ...      ...     ...
# 95  2024-07-18  12:00:00  337.810  338.050  336.540  337.040  165245
# 96  2024-07-18  11:45:00  339.020  339.685  336.340  337.940  210654
# 97  2024-07-18  11:30:00  340.580  340.800  338.658  339.060  199683
# 98  2024-07-18  11:15:00  341.910  342.371  340.200  340.755  127691
# 99  2024-07-18  11:00:00  344.885  346.050  341.510  341.700  137984
#
# [100 rows x 7 columns]

# %%
data.head(5)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2024-01-02  251.470001  252.289993  243.029999  246.889999  246.889999
# 1  2024-01-03  240.320007  248.830994  238.610001  244.360001  244.360001
# 2  2024-01-04  246.000000  247.610001  243.639999  245.649994  245.649994
# 3  2024-01-05  245.000000  249.479996  244.649994  247.460007  247.460007
# 4  2024-01-08  251.899994  261.639008  251.559998  261.279999  261.279999
#
#     Volume
# 0  3756800
# 1  3157600
# 2  2103000
# 3  2405900
# 4  4009200

# %%
data1.tail(20)
# Out:
#            Date      Time     Open    High     Low   Close  Volume
# 855  2024-07-01  08:45:00  384.570  385.10  384.21  384.88     932
# 856  2024-07-01  08:30:00  384.940  388.61  384.20  384.60     595
# 857  2024-07-01  08:15:00  383.982  386.20  383.19  385.49    1349
# 858  2024-07-01  08:00:00  384.000  386.46  381.30  384.74    1775
# 859  2024-07-01  07:45:00  384.300  384.46  383.76  384.46     118
# 860  2024-07-01  07:30:00  383.750  384.46  383.75  384.16     383
# 861  2024-07-01  07:15:00  383.050  384.00  383.05  383.96     690
# 862  2024-07-01  07:00:00  382.860  383.30  382.45  383.03     343
# 863  2024-07-01  06:45:00  382.950  382.95  382.40  382.45      11
# 864  2024-07-01  06:30:00  382.400  382.42  382.40  382.42       6
# 865  2024-07-01  06:15:00  382.170  382.40  382.14  382.40      36
# 866  2024-07-01  06:00:00  382.350  382.55  382.10  382.12      72
# 867  2024-07-01  05:45:00  382.050  382.43  382.00  382.35      25
# ...

# %%
plt.figure(figsize=(11, 6))
plt.plot(data1.Volume)
plt.ylabel('Stock Volume')
plt.xlabel('In 15 minues')
plt.show()

# %%
plt.figure(figsize=(11, 6))
plt.plot(data1.Close)
plt.ylabel('Stock Price($)')
plt.xlabel('Date')
plt.show()

# %%
plt.figure(figsize=(11, 6))
plt.plot(data1.Close)
plt.ylabel('Stock Price($)')
plt.xlabel('Date')
plt.show()

# %%
fig, axs= plt.subplots(2,1, gridspec_kw={"height_ratios": [3,1]}, figsize=(13,7))

axs[0].plot(data['Close'])
axs[1].axhline(y=360, color='r', linestyle='--')
axs[1].axhline(y=300, color='g', linestyle='--')
axs[1].plot(data['Close'],color='orange')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bf3c13c1a915> in <cell line: 1>()
# ----> 1 fig, axs= plt.subplots(2,1, gridspec_kw={"height_ratios": [3,1]}, figsize=(13,7))
#       2
#       3 axs[0].plot(data['Close'])
#       4 axs[1].axhline(y=360, color='r', linestyle='--')
#       5 axs[1].axhline(y=300, color='g', linestyle='--')
#
# NameError: name 'plt' is not defined

# %%
fig, axs= plt.subplots(2,1, gridspec_kw={"height_ratios": [3,1]}, figsize=(13,7))

axs[0].plot(data1['Close'])
axs[1].axhline(y=360, color='r', linestyle='--')
axs[1].axhline(y=300, color='g', linestyle='--')
axs[1].plot(data1['Close'])

# %%
start= dt.datetime(2024,7,4)
end=dt.datetime(2024,7,12)
range=pd.range(start,end)

fig,axs = plt.subplots(2,1,gridspec_kw={"height_ratios": [3,1]},figsize=(13,7))

axs[0].plot((x==range,y=={0,100,200,300,400}),data1.Close)
axs[1].axhline(y=360, color='r', linestyle='--')
axs[1].axhline(y=300, color='g', linestyle='--')
axs[1].plot(data['Close'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-212-aec8a4e389ad> in <cell line: 3>()
#       1 start= dt.datetime(2024,7,4)
#       2 end=dt.datetime(2024,7,12)
# ----> 3 range=pd.range(start,end)
#       4
#       5 fig,axs = plt.subplots(2,1,gridspec_kw={"height_ratios": [3,1]},figsize=(13,7))
#
# AttributeError: module 'pandas' has no attribute 'range'
