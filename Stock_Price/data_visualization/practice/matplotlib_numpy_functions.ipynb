# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(-100,100,1)
y1 = 0.5 * x ** 2 + 2 * x
y2 = np.sin(x) * 1000
y3 = np.log(x) * 1000
plt.figure(figsize=(13,7))
plt.plot(x,y1, label='squer function')
plt.plot(x,y2, label='sin function')
plt.plot(x,y3, label='log function')
plt.title("Function Diagram",size=20)
plt.ylabel("Y-axis",size=15)
plt.xlabel("X-axis",size=15)
plt.legend()
plt.show()
# Out:
# <ipython-input-11-905d4d736881>:4: RuntimeWarning: divide by zero encountered in log
#   y3 = np.log(x) * 1000
# <ipython-input-11-905d4d736881>:4: RuntimeWarning: invalid value encountered in log
#   y3 = np.log(x) * 1000
